# %%
import pandas as pd

# %%
povertyestimates = pd.read_csv('povertydata.csv')
education = pd.read_csv('education_final.csv')
unemployment = pd.read_csv('unemployment.csv')
death = pd.read_csv('death_final.csv', nrows = 3144)

# %%
povertyestimates = povertyestimates.rename(columns = {'FIPStxt': 'FIPS'})
povertyestimates = povertyestimates.rename(columns = {'Stabr': 'State'})
povertyestimates
# Out:
#        FIPS State          Area_name  Rural-urban_Continuum_Code_2003  \
# 0         0    US      United States                              NaN
# 1      1000    AL            Alabama                              NaN
# 2      1001    AL     Autauga County                              2.0
# 3      1003    AL     Baldwin County                              4.0
# 4      1005    AL     Barbour County                              6.0
# ...     ...   ...                ...                              ...
# 3188  56037    WY  Sweetwater County                              5.0
# 3189  56039    WY       Teton County                              7.0
# 3190  56041    WY       Uinta County                              7.0
# 3191  56043    WY    Washakie County                              7.0
# 3192  56045    WY      Weston County                              7.0
#
#       Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# ...

# %%
education = education.rename(columns = {'FIPS Code': 'FIPS'})
education
# Out:
#        FIPS State            Area name  2013 Rural-urban Continuum Code  \
# 0         0    US        United States                              NaN
# 1      1000    AL              Alabama                              NaN
# 2      1001    AL       Autauga County                              2.0
# 3      1003    AL       Baldwin County                              3.0
# 4      1005    AL       Barbour County                              6.0
# ...     ...   ...                  ...                              ...
# 3278  72145    PR  Vega Baja Municipio                              1.0
# 3279  72147    PR    Vieques Municipio                              7.0
# 3280  72149    PR   Villalba Municipio                              2.0
# 3281  72151    PR    Yabucoa Municipio                              1.0
# 3282  72153    PR      Yauco Municipio                              2.0
#
#       2013 Urban Influence Code  \
# 0                           NaN
# 1                           NaN
# ...

# %%
unemployment = unemployment.rename(columns = {'FIPS_Code': 'FIPS'})
unemployment
# Out:
#        FIPS State                Area_name  Rural_urban_continuum_code_2013  \
# 0         0    US            United States                              NaN
# 1      1000    AL                  Alabama                              NaN
# 2      1001    AL       Autauga County, AL                              2.0
# 3      1003    AL       Baldwin County, AL                              3.0
# 4      1005    AL       Barbour County, AL                              6.0
# ...     ...   ...                      ...                              ...
# 3270  72145    PR  Vega Baja Municipio, PR                              1.0
# 3271  72147    PR    Vieques Municipio, PR                              7.0
# 3272  72149    PR   Villalba Municipio, PR                              2.0
# 3273  72151    PR    Yabucoa Municipio, PR                              1.0
# 3274  72153    PR      Yauco Municipio, PR                              2.0
#
# ...

# %%
death
# Out:
#        FIPS Age-Adjusted Death Rate([rate note]) - deaths per 100,000
# 0         0                                              152.4
# 1     12125                                              441.1
# 2     51640                                              384.3
# 3     20095                                              315.8
# 4     51580                                              293.1
# ...     ...                                                ...
# 3137  30103                                                 *
# 3138  31183                                                 *
# 3139  30109                                                 *
# 3140   2282                                                 *
# 3141  46137                                                 *
#
# [3142 rows x 2 columns]
